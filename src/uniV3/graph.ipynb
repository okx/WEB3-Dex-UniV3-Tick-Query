# %%
import matplotlib.pyplot as plt
import numpy as np

# xpoints = np.array([-887272,887272])
# ypoints = np.array([10,10])
x2points = np.array([-300000,-200000])
y2points = np.array([100,100])
x3points = np.array([-100000,0])
y3points = np.array([80,80])
# plt.plot(xpoints,ypoints, marker = 'o')
plt.plot(x2points,y2points, marker = 'o')
plt.plot(x3points,y3points, marker = 'o')
plt.xlabel("tick")
plt.ylabel("L")
plt.title("Uniswap L Vs Tick")
plt.show()
